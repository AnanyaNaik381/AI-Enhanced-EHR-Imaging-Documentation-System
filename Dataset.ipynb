# %% [markdown]
# <a href="https://colab.research.google.com/github/AnanyaNaik381/AI-Enhanced-EHR-Imaging-Documentation-System/blob/main/Dataset.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df_prescription=pd.read_csv("/content/health prescription data.csv")

# %%
df_healthcare=pd.read_csv("/content/healthcare_dataset.csv")

# %%
df_lab=pd.read_csv("/content/Lab Results.csv")

# %%
print(df_prescription.head())
# Out:
#   application_number          sponsor_name  brand_name  product_number  \
# 0          NDA000004              PHARMICS   PAREDRINE               4
# 1          NDA017377  SUN PHARM INDUSTRIES     BACTRIM               1
# 2          NDA017377  SUN PHARM INDUSTRIES  BACTRIM DS               2
# 3         ANDA076177     DR REDDYS LABS SA      CAMILA               1
# 4         ANDA076182                  TEVA   OFLOXACIN               3
#
#   reference_drug                              active_ingredients  \
# 0             No            HYDROXYAMPHETAMINE HYDROBROMIDE (1%)
# 1            Yes   SULFAMETHOXAZOLE (400MG), TRIMETHOPRIM (80MG)
# 2            Yes  SULFAMETHOXAZOLE (800MG), TRIMETHOPRIM (160MG)
# 3             No                          NORETHINDRONE (0.35MG)
# 4             No                               OFLOXACIN (400MG)
#
#   referenced_standard     dosage_form       route marketing_status
# 0                  No  SOLUTION/DROPS  OPHTHALMIC     Discontinued
# ...

# %%
print(df_healthcare.head())
# Out:
#             Name  Age  Gender Blood Type Medical Condition Date of Admission  \
# 0  Bobby JacksOn   30    Male         B-            Cancer        2024-01-31
# 1   LesLie TErRy   62    Male         A+           Obesity        2019-08-20
# 2    DaNnY sMitH   76  Female         A-           Obesity        2022-09-22
# 3   andrEw waTtS   28  Female         O+          Diabetes        2020-11-18
# 4  adrIENNE bEll   43  Female        AB+            Cancer        2022-09-19
#
#              Doctor                    Hospital Insurance Provider  \
# 0     Matthew Smith             Sons and Miller         Blue Cross
# 1   Samantha Davies                     Kim Inc           Medicare
# 2  Tiffany Mitchell                    Cook PLC              Aetna
# 3       Kevin Wells  Hernandez Rogers and Vang,           Medicare
# 4    Kathleen Hanna                 White-White              Aetna
#
#    Billing Amount  Room Number Admission Type Discharge Date   Medication  \
# ...

# %%
print(df_lab.head())
# Out:
#    HAEMATOCRIT  HAEMOGLOBINS  ERYTHROCYTE  LEUCOCYTE  THROMBOCYTE   MCH  MCHC  \
# 0         35.1          11.8         4.65        6.3          310  25.4  33.6
# 1         43.5          14.8         5.39       12.7          334  27.5  34.0
# 2         33.5          11.3         4.74       13.2          305  23.8  33.7
# 3         39.1          13.7         4.98       10.5          366  27.5  35.0
# 4         30.9           9.9         4.23       22.1          333  23.4  32.0
#
#     MCV  AGE SEX SOURCE
# 0  75.5    1   F    out
# 1  80.7    1   F    out
# 2  70.7    1   F    out
# 3  78.5    1   F    out
# 4  73.0    1   M    out

# %%
print(df_healthcare.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 48501 entries, 0 to 48500
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                48501 non-null  object
#  1   Age                 48501 non-null  int64
#  2   Gender              48501 non-null  object
#  3   Blood Type          48501 non-null  object
#  4   Medical Condition   48501 non-null  object
#  5   Date of Admission   48501 non-null  object
#  6   Doctor              48501 non-null  object
#  7   Hospital            48500 non-null  object
#  8   Insurance Provider  48500 non-null  object
#  9   Billing Amount      48500 non-null  float64
#  10  Room Number         48500 non-null  float64
#  11  Admission Type      48500 non-null  object
#  12  Discharge Date      48500 non-null  object
#  13  Medication          48500 non-null  object
#  14  Test Results        48500 non-null  object
# ...

# %%
print(df_prescription.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16918 entries, 0 to 16917
# Data columns (total 10 columns):
#  #   Column               Non-Null Count  Dtype
# ---  ------               --------------  -----
#  0   application_number   16918 non-null  object
#  1   sponsor_name         16918 non-null  object
#  2   brand_name           16918 non-null  object
#  3   product_number       16918 non-null  int64
#  4   reference_drug       16918 non-null  object
#  5   active_ingredients   16918 non-null  object
#  6   referenced_standard  16393 non-null  object
#  7   dosage_form          16918 non-null  object
#  8   route                16879 non-null  object
#  9   marketing_status     16918 non-null  object
# dtypes: int64(1), object(9)
# memory usage: 1.3+ MB
# None

# %%
print(df_lab.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4412 entries, 0 to 4411
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   HAEMATOCRIT   4412 non-null   float64
#  1   HAEMOGLOBINS  4412 non-null   float64
#  2   ERYTHROCYTE   4412 non-null   float64
#  3   LEUCOCYTE     4412 non-null   float64
#  4   THROMBOCYTE   4412 non-null   int64
#  5   MCH           4412 non-null   float64
#  6   MCHC          4412 non-null   float64
#  7   MCV           4412 non-null   float64
#  8   AGE           4412 non-null   int64
#  9   SEX           4412 non-null   object
#  10  SOURCE        4412 non-null   object
# dtypes: float64(7), int64(2), object(2)
# memory usage: 379.3+ KB
# None

# %%
print(df_prescription.describe())
# Out:
#        product_number
# count    16918.000000
# mean         1.936222
# std          1.550021
# min          0.000000
# 25%          1.000000
# 50%          1.000000
# 75%          2.000000
# max         26.000000

# %%
print(df_healthcare.describe())
# Out:
#                 Age  Billing Amount   Room Number
# count  48501.000000    48500.000000  48500.000000
# mean      51.597988    25563.788862    301.097711
# std       19.575619    14213.507307    115.170124
# min       18.000000    -2008.492140    101.000000
# 25%       35.000000    13250.792775    202.000000
# 50%       52.000000    25544.938022    302.000000
# 75%       69.000000    37850.164225    400.000000
# max       85.000000    52764.276736    500.000000

# %%
print(df_lab.describe())
# Out:
#        HAEMATOCRIT  HAEMOGLOBINS  ERYTHROCYTE    LEUCOCYTE  THROMBOCYTE  \
# count  4412.000000   4412.000000  4412.000000  4412.000000  4412.000000
# mean     38.197688     12.741727     4.541260     8.718608   257.524479
# std       5.974784      2.079903     0.784091     5.049041   113.972365
# min      13.700000      3.800000     1.480000     1.100000     8.000000
# 25%      34.375000     11.400000     4.040000     5.675000   188.000000
# 50%      38.600000     12.900000     4.570000     7.600000   256.000000
# 75%      42.500000     14.200000     5.050000    10.300000   321.000000
# max      69.000000     18.900000     7.860000    76.600000  1183.000000
#
#                MCH         MCHC          MCV          AGE
# count  4412.000000  4412.000000  4412.000000  4412.000000
# mean     28.234701    33.343042    84.612942    46.626473
# std       2.672639     1.228664     6.859101    21.731218
# min      14.900000    26.000000    54.000000     1.000000
# ...

# %%
print(df_lab.isnull().sum)
# Out:
# <bound method DataFrame.sum of       HAEMATOCRIT  HAEMOGLOBINS  ERYTHROCYTE  LEUCOCYTE  THROMBOCYTE    MCH  \
# 0           False         False        False      False        False  False
# 1           False         False        False      False        False  False
# 2           False         False        False      False        False  False
# 3           False         False        False      False        False  False
# 4           False         False        False      False        False  False
# ...           ...           ...          ...        ...          ...    ...
# 4407        False         False        False      False        False  False
# 4408        False         False        False      False        False  False
# 4409        False         False        False      False        False  False
# 4410        False         False        False      False        False  False
# 4411        False         False        False      False        False  False
#
# ...

# %%
print(df_prescription.isnull().sum)
# Out:
# <bound method DataFrame.sum of        application_number  sponsor_name  brand_name  product_number  \
# 0                   False         False       False           False
# 1                   False         False       False           False
# 2                   False         False       False           False
# 3                   False         False       False           False
# 4                   False         False       False           False
# ...                   ...           ...         ...             ...
# 16913               False         False       False           False
# 16914               False         False       False           False
# 16915               False         False       False           False
# 16916               False         False       False           False
# 16917               False         False       False           False
#
#        reference_drug  active_ingredients  referenced_standard  dosage_form  \
# ...

# %%
print(df_healthcare.isnull().sum)
# Out:
# <bound method DataFrame.sum of         Name    Age  Gender  Blood Type  Medical Condition  Date of Admission  \
# 0      False  False   False       False              False              False
# 1      False  False   False       False              False              False
# 2      False  False   False       False              False              False
# 3      False  False   False       False              False              False
# 4      False  False   False       False              False              False
# ...      ...    ...     ...         ...                ...                ...
# 48496  False  False   False       False              False              False
# 48497  False  False   False       False              False              False
# 48498  False  False   False       False              False              False
# 48499  False  False   False       False              False              False
# 48500  False  False   False       False              False              False
#
# ...

# %%
print(df_lab.duplicated().sum)
# Out:
# <bound method Series.sum of 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4407    False
# 4408    False
# 4409    False
# 4410    False
# 4411    False
# Length: 4412, dtype: bool>

# %%
print(df_prescription.duplicated().sum)
# Out:
# <bound method Series.sum of 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 16913    False
# 16914    False
# 16915    False
# 16916    False
# 16917    False
# Length: 16918, dtype: bool>

# %%
print(df_healthcare.duplicated().sum)
# Out:
# <bound method Series.sum of 0        False
# 1        False
# 2        False
# 3        False
# 4        False
#          ...
# 48496    False
# 48497    False
# 48498    False
# 48499    False
# 48500    False
# Length: 48501, dtype: bool>

# %%
print(df_healthcare.shape)
# Out:
# (48501, 15)

# %%
print(df_prescription.shape)
# Out:
# (16918, 10)

# %%
print(df_lab.shape)
# Out:
# (4412, 11)

# %%
print(df_prescription.dtypes)
# Out:
# application_number     object
# sponsor_name           object
# brand_name             object
# product_number          int64
# reference_drug         object
# active_ingredients     object
# referenced_standard    object
# dosage_form            object
# route                  object
# marketing_status       object
# dtype: object

# %%
print(df_lab.dtypes)
# Out:
# HAEMATOCRIT     float64
# HAEMOGLOBINS    float64
# ERYTHROCYTE     float64
# LEUCOCYTE       float64
# THROMBOCYTE       int64
# MCH             float64
# MCHC            float64
# MCV             float64
# AGE               int64
# SEX              object
# SOURCE           object
# dtype: object

# %%
print(df_healthcare.dtypes)
# Out:
# Name                   object
# Age                     int64
# Gender                 object
# Blood Type             object
# Medical Condition      object
# Date of Admission      object
# Doctor                 object
# Hospital               object
# Insurance Provider     object
# Billing Amount        float64
# Room Number           float64
# Admission Type         object
# Discharge Date         object
# Medication             object
# Test Results           object
# dtype: object

# %%
num_cols = df_prescription.select_dtypes(include=['int64', 'float64']).columns
cat_cols = df_prescription.select_dtypes(include=['object', 'category']).columns

print("\nNumerical Columns:", list(num_cols))
print("Categorical Columns:", list(cat_cols))
# Out:
# Numerical Columns: ['product_number']
# Categorical Columns: ['application_number', 'sponsor_name', 'brand_name', 'reference_drug', 'active_ingredients', 'referenced_standard', 'dosage_form', 'route', 'marketing_status']

# %%
num_cols = df_healthcare.select_dtypes(include=['int64', 'float64']).columns
cat_cols = df_healthcare.select_dtypes(include=['object', 'category']).columns

print("\nNumerical Columns:", list(num_cols))
print("Categorical Columns:", list(cat_cols))
# Out:
# Numerical Columns: ['Age', 'Billing Amount', 'Room Number']
# Categorical Columns: ['Name', 'Gender', 'Blood Type', 'Medical Condition', 'Date of Admission', 'Doctor', 'Hospital', 'Insurance Provider', 'Admission Type', 'Discharge Date', 'Medication', 'Test Results']

# %%
num_cols = df_lab.select_dtypes(include=['int64', 'float64']).columns
cat_cols = df_lab.select_dtypes(include=['object', 'category']).columns

print("\nNumerical Columns:", list(num_cols))
print("Categorical Columns:", list(cat_cols))
# Out:
# Numerical Columns: ['HAEMATOCRIT', 'HAEMOGLOBINS', 'ERYTHROCYTE', 'LEUCOCYTE', 'THROMBOCYTE', 'MCH', 'MCHC', 'MCV', 'AGE']
# Categorical Columns: ['SEX', 'SOURCE']

# %%
num_cols = df_prescription.select_dtypes(include=['int64', 'float64']).columns
df_prescription[num_cols].hist(figsize=(15, 10))
plt.tight_layout()
plt.show()

# %%
num_cols = df_lab.select_dtypes(include=['int64', 'float64']).columns
df_lab[num_cols].hist(figsize=(15, 10))
plt.tight_layout()
plt.show()

# %%
num_cols = df_healthcare.select_dtypes(include=['int64', 'float64']).columns
df_healthcare[num_cols].hist(figsize=(15, 10))
plt.tight_layout()
plt.show()

# %%
num_cols = df_prescription.select_dtypes(include=['int64', 'float64']).columns
plt.figure(figsize=(15, 10))
sns.boxplot(data=df_prescription[num_cols])
plt.title('Boxplots of Numerical Columns in df_prescription')
plt.xticks(rotation=45, ha='right')
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py'>

# %%
num_cols = df_healthcare.select_dtypes(include=['int64', 'float64']).columns
plt.figure(figsize=(15, 10))
sns.boxplot(data=df_healthcare[num_cols])
plt.title('Boxplots of Numerical Columns in df_prescription')
plt.xticks(rotation=45, ha='right')
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py'>

# %%
num_cols=df_lab.select_dtypes(include=['int64','float64']).columns
correlation_matrix=df_lab[num_cols].corr()
plt.figure(figsize=(12,8))
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm',fmt=".2f")
plt.title('Correlation Heatmap of Numerical Columns in df_lab')
plt.show()

# %%
num_cols=df_healthcare.select_dtypes(include=['int64','float64']).columns
correlation_matrix=df_healthcare[num_cols].corr()
plt.figure(figsize=(12,8))
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm',fmt=".2f")
plt.title('Correlation Heatmap of Numerical Columns in df_healthcare')
plt.show()

# %%
num_cols = df_lab.select_dtypes(include=['int64', 'float64']).columns
plt.figure(figsize=(15, 10))
sns.boxplot(data=df_lab[num_cols])
plt.title('Boxplots of Numerical Columns in df_prescription')
plt.xticks(rotation=45, ha='right')
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py'>

# %%
num_cols=df_healthcare.select_dtypes(include=['int64','float64']).columns
correlation_matrix=df_healthcare[num_cols].corr()
plt.figure(figsize=(12,8))
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm',fmt=".2f")
plt.title('Correlation Heatmap of Numerical Columns in df_healthcare')
plt.show()

# %%
num_cols=df_prescription.select_dtypes(include=['int64','float64']).columns
correlation_matrix=df_prescription[num_cols].corr()
plt.figure(figsize=(12,8))
sns.heatmap(correlation_matrix,annot=True,cmap='coolwarm',fmt=".2f")
plt.title('Correlation Heatmap of Numerical Columns in df_prescription')
plt.show()

# %%
num_cols = df_healthcare.select_dtypes(include=['int64', 'float64']).columns
sns.pairplot(df_healthcare[num_cols])
plt.suptitle('Pairplot of Numerical Columns in df_healthcare', y=1.02)
plt.show()

# %%
num_cols = df_prescription.select_dtypes(include=['int64', 'float64']).columns
sns.pairplot(df_prescription[num_cols])
plt.suptitle('Pairplot of Numerical Columns in df_prescription', y=1.02)
plt.show()

# %%
num_cols = df_healthcare.select_dtypes(include=['int64', 'float64']).columns
sns.pairplot(df_healthcare[num_cols])
plt.suptitle('Pairplot of Numerical Columns in df_healthcare', y=1.02)
plt.show()

# %%
num_cols = df_lab.select_dtypes(include=['int64', 'float64']).columns
sns.pairplot(df_lab[num_cols])
plt.suptitle('Pairplot of Numerical Columns in df_lab', y=1.02)
plt.show()
